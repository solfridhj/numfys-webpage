# %% [markdown]
# ## Testing av Jupyter notebooks

# %% [markdown]
# Oppgave $\alpha$.
#
# Plot funksjonen.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 4*np.pi, 200)
y = np.cos(x)

plt.plot(x, y, label=r'$\cos(x)$')
plt.title("Ett enkelt eksempel")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(fancybox=True, shadow=True)
plt.show()

# %% [markdown]
# Skriv kode under:

# %%
def plot_something():
    # CODE HERE
    return
